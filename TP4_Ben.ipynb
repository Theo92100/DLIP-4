# %% [markdown]
# # TP4 :  Learning on a low budget
# **Théo Rudkiewicz, Cyriaque Rousselot**

# %% [markdown]
# # Introduction
#
# **Context :**
#
# Assume we are in a context where few "gold" labeled data samples are available for training, say
#
# $$\mathcal{X}_{\text{train}} = \{(x_n,y_n)\}_{n\leq N_{\text{train}}}$$
#
# where $N_{\text{train}}$ is small.
#
# A large test set $\mathcal{X}_{\text{test}}$ exists but is not accessible.
# (To make your task easier, we provide you with some data (named `test_dataset` in the code) that you can use to test your model, but you **must not** use it to train your model).
#
# We also assume that we have a limited computational budget.
#
# The goal of this practical session is to guide you through different methods that will help you get better results from few resources (data & compute).

# %% [markdown]
# In this practical, we will use the `resnet18` architecture. We will use models from the [pytorch vision hub ](https://pytorch.org/vision/stable/models.html#).

# %% [markdown]
# # QUESTIONS
#
# ## Grading
#
# You will be graded on 5 questions. You will need to provide 7 files :
# 1. This Notebook
# 2. `utils.py`
# 3. `last_layer_finetune.pth` (the file **must be of size less than 5Mo**)
# 4. `daug_resnet.pth` (the file **must be of size less than 50Mo**)
# 5. `final_model.pth` (the file **must be of size less than 50Mo**)
# 6. `drawing_lora.png`
# 7. `cutmix.png`
#
# If the code you defined passes all our tests, you will get the full grade. Otherwise we  will look at the intermediate questions in the notebook to give you partial credit.
#
#
#
#  Please provide clear and short answers between `<div class="alert alert-info">  <your answer>  </div>` tags (when it's not code).

# %% [markdown]
# <div class="alert alert-info">  Example of answer  </div>

# %%
import os

if not os.path.exists("data"):
    os.mkdir("data")
if not os.path.exists("data/TP4_images"):
    os.mkdir("data/TP4_images")
    # !cd data/TP4_images && wget -O north_dataset_train.zip  "https://nextcloud.lisn.upsaclay.fr/index.php/s/yzQRWE2YjmFn9WA/download/north_dataset_train.zip" && unzip north_dataset_train.zip
    # !cd data/TP4_images && wget -O north_dataset_test.zip  "https://nextcloud.lisn.upsaclay.fr/index.php/s/zntidWrFdYsGMDm/download/north_dataset_test.zip" && unzip north_dataset_test.zip
dir_path = "data/TP4_images/"

# %%
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (1.7.0)
# Requirement already satisfied: numpy>1.20.0 in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from torchmetrics) (24.1)
# Requirement already satisfied: torch>=2.0.0 in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from torchmetrics) (2.4.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from torchmetrics) (0.14.2)
# Requirement already satisfied: setuptools in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from lightning-utilities>=0.8.0->torchmetrics) (72.1.0)
# Requirement already satisfied: typing_extensions in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.11.0)
# Requirement already satisfied: filelock in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.3)
# Requirement already satisfied: jinja2 in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->torchmetrics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages (from sympy->torch>=2.0.0->torchmetrics) (1.3.0)

# %%
import torch
import torch.nn as nn
from torchvision import datasets, transforms, models
from torchmetrics.classification import BinaryAccuracy, Accuracy, ConfusionMatrix
# you can install torchmetrics with `pip install torchmetrics`
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from utils import precompute_features, LastLayer  # Import your functions and modules

# device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

north_dataset = datasets.ImageFolder(
    dir_path + "north_dataset_sample",
    transform=transforms.Compose([transforms.ToTensor()]),
)
test_dataset = datasets.ImageFolder(
    dir_path + "north_dataset_test",
    transform=transforms.Compose([transforms.ToTensor()]),
)
base_model = models.resnet18()

# %% [markdown]
# ## Question 1 :
# >  Change the last layer of the resnet model so that its size fits the problem.

# %% [markdown]
# <div class="alert alert-info">  The last Resnet18 is a fully connected layer with an output dimension of 1000 (as the model is meant to be used as a classifier for up to 1000 classes). We change that dimension to 2, as the problem at hand is binary classification. </div>

# %%
# Change to 2 layers the last linear
print(f"Before :")
print(f"base_model.fc : {base_model.fc}")
in_features = base_model.fc.in_features
base_model.fc = nn.Linear(in_features, 2)
print(f"After :")
print(f"base_model.fc : {base_model.fc}")
# Out:
# Before :
# base_model.fc : Linear(in_features=512, out_features=1000, bias=True)
# After :
# base_model.fc : Linear(in_features=512, out_features=2, bias=True)

# %%
assert (
    base_model.fc.out_features == 2
)  # we could also change the last layer to have 1 output. Do it with 2 so that it matches our tests procedure during grading.

# %% [markdown]
# ### Utility functions for training

# %%
def training(model, train_loader, test_dataloader, criterion, optimizer, num_epochs=20, ):
    """full training loop
    """

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        # train the model
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * features.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / total
        epoch_acc = correct / total
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)
        
        # evaluate the model
        model.eval()
        correct = 0
        test_running_loss = 0.0
        total = 0
        
        for features, labels in test_dataloader:
            features, labels = features.to(device), labels.to(device)
            with torch.no_grad():
                outputs = model(features)
                loss = criterion(outputs, labels)
                test_running_loss += loss.item() * features.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            
        test_loss = test_running_loss / total
        test_acc = correct / total
        test_losses.append(test_loss)
        test_accuracies.append(test_acc)

        print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {epoch_loss:.4f}, Training accuracy: {epoch_acc:.4f}, Test Loss: {test_loss:.4f}, Test accuracy: {test_acc:.4f}")
        
    return train_losses, train_accuracies, test_losses, test_accuracies

# %%
def plot_results(train_losses, train_accuracies, test_losses, test_accuracies):
    """ utility function to plot results
    """
    
    plt.figure(figsize=(12,5))

    plt.subplot(1,2,1)
    plt.plot(train_losses, marker='o', label='Train Loss')
    plt.plot(test_losses, marker='o', label='Test Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss Curves')
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(train_accuracies, marker='o', label='Train Accuracy')
    plt.plot(test_accuracies, marker='o', label='Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Question 2:
# > Train the last layer of a randomly initialized resnet model. Provide a function precompute_features in `utils.py` that creates a new dataset from the features precomputed by the model.
#
# Intermediate question :  Provide the training process in the notebook with training curve. Comment on the accuracy.

# %%
resnet = models.resnet18(weights=None)  # randomly initialized
resnet.fc = nn.Identity()
resnet.to(device)

precomputed_dataset = precompute_features(resnet, north_dataset, device)
precomputed_test_dataset = precompute_features(resnet, test_dataset, device) # add Ben

# Create a DataLoader for the new dataset
train_loader = DataLoader(precomputed_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(precomputed_test_dataset, batch_size=32, shuffle=False) # add Ben

# 2. Create the last layer model that takes the precomputed features as input.
last_layer = LastLayer().to(device)

# 3. Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(last_layer.parameters(), lr=1e-3) #adjust the lr maybe

# %%
train_losses, train_accuracies, test_losses, test_accuracies = training(
    last_layer, 
    train_loader, 
    test_dataloader, 
    criterion, 
    optimizer, 
    num_epochs=20)

plot_results(train_losses, train_accuracies, test_losses, test_accuracies)
# Out:
# Epoch 1/20, Training Loss: 0.6508, Training accuracy: 0.7381, Test Loss: 0.8055, Test accuracy: 0.5000
# Epoch 2/20, Training Loss: 0.5907, Training accuracy: 0.7381, Test Loss: 0.9093, Test accuracy: 0.5000
# Epoch 3/20, Training Loss: 0.6022, Training accuracy: 0.7381, Test Loss: 0.9291, Test accuracy: 0.5000
# Epoch 4/20, Training Loss: 0.6048, Training accuracy: 0.7381, Test Loss: 0.9450, Test accuracy: 0.5000
# Epoch 5/20, Training Loss: 0.6089, Training accuracy: 0.7381, Test Loss: 0.9092, Test accuracy: 0.5000
# Epoch 6/20, Training Loss: 0.6084, Training accuracy: 0.7381, Test Loss: 0.8513, Test accuracy: 0.5000
# Epoch 7/20, Training Loss: 0.5890, Training accuracy: 0.7381, Test Loss: 0.8278, Test accuracy: 0.5000
# Epoch 8/20, Training Loss: 0.5856, Training accuracy: 0.7381, Test Loss: 0.8047, Test accuracy: 0.5000
# Epoch 9/20, Training Loss: 0.5873, Training accuracy: 0.7381, Test Loss: 0.7814, Test accuracy: 0.5000
# Epoch 10/20, Training Loss: 0.5887, Training accuracy: 0.7381, Test Loss: 0.7784, Test accuracy: 0.5000
# Epoch 11/20, Training Loss: 0.5882, Training accuracy: 0.7381, Test Loss: 0.7892, Test accuracy: 0.5000
# Epoch 12/20, Training Loss: 0.5878, Training accuracy: 0.7381, Test Loss: 0.7970, Test accuracy: 0.5000
# Epoch 13/20, Training Loss: 0.5856, Training accuracy: 0.7381, Test Loss: 0.7926, Test accuracy: 0.5000
# Epoch 14/20, Training Loss: 0.5862, Training accuracy: 0.7381, Test Loss: 0.7886, Test accuracy: 0.5000
# Epoch 15/20, Training Loss: 0.5855, Training accuracy: 0.7381, Test Loss: 0.7972, Test accuracy: 0.5000
# Epoch 16/20, Training Loss: 0.5853, Training accuracy: 0.7381, Test Loss: 0.8145, Test accuracy: 0.5000
# Epoch 17/20, Training Loss: 0.5846, Training accuracy: 0.7381, Test Loss: 0.8501, Test accuracy: 0.5000
# Epoch 18/20, Training Loss: 0.5855, Training accuracy: 0.7381, Test Loss: 0.8690, Test accuracy: 0.5000
# Epoch 19/20, Training Loss: 0.5913, Training accuracy: 0.7381, Test Loss: 0.8632, Test accuracy: 0.5000
# Epoch 20/20, Training Loss: 0.5872, Training accuracy: 0.7381, Test Loss: 0.8261, Test accuracy: 0.5000

# %% [markdown]
# <div class="alert alert-info"> In this example, we first replace the final fully connected layer of the randomly initialized ResNet18 with an identity layer so that we can precompute the intermediate features using the provided <code>precompute_features</code> function. Then we train a separate <code>LastLayer</code> model on these features using cross-entropy loss. The training loop runs for 20 epochs, and we record and plot the loss and accuracy after each epoch.
# Because the ResNet feature extractor is randomly initialized, the precomputed features are not very meaningful. As a result, you may observe that the accuracy stays the same throughout the procedure here 0.73 even though the training loss decreases. This highlights the importance of using a pretrained feature extractor for better performance.
# </div>

# %% [markdown]
# ## Question 3 :
# > Now start from a pretained model on Imagenet (https://pytorch.org/vision/stable/models.html#) and only train the last layer. Provide the training process in the notebook with training curve.
#
#  Provide two files : (https://pytorch.org/tutorials/beginner/saving_loading_models.html)
#  -  a file  `utils.py` containing only the last layer class `LastLayer` inheriting from `torch.nn.Module` architecture of your final model to load
#  -  a `last_layer_finetune.pth` file containing __only the last layer weights__ ( we will check the size)
#
#  We will test your model on final accuracy on a test set.

# %%
training_dataloader= DataLoader(north_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Load the pretrained ResNet18 model
resnet = models.resnet18(weights="IMAGENET1K_V1")

# Replace the final fully connected layer with our custom LastLayer
resnet.fc = LastLayer()
resnet = resnet.to(device)

# Freeze all parameters except the ones in the final layer
for name, param in resnet.named_parameters():
    if "fc" not in name:
        param.requires_grad = False

# Define loss function and optimizer (only for last layer parameters)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(resnet.fc.parameters(), lr=1e-3)

# %%
train_losses, train_accuracies, test_losses, test_accuracies = training(
    resnet, 
    training_dataloader, 
    test_dataloader, 
    criterion, 
    optimizer, 
    num_epochs=20)

plot_results(train_losses, train_accuracies, test_losses, test_accuracies)

# Save only the last layer's weights
torch.save(resnet.fc.state_dict(), "last_layer_finetune.pth")
# Out:
# Epoch 1/20, Training Loss: 0.6593, Training accuracy: 0.5952, Test Loss: 0.9938, Test accuracy: 0.5000
# Epoch 2/20, Training Loss: 0.6145, Training accuracy: 0.7381, Test Loss: 1.0005, Test accuracy: 0.5000
# Epoch 3/20, Training Loss: 0.5304, Training accuracy: 0.7381, Test Loss: 0.8386, Test accuracy: 0.5000
# Epoch 4/20, Training Loss: 0.4986, Training accuracy: 0.7619, Test Loss: 0.7224, Test accuracy: 0.5238
# Epoch 5/20, Training Loss: 0.4739, Training accuracy: 0.8333, Test Loss: 0.7061, Test accuracy: 0.5238
# Epoch 6/20, Training Loss: 0.4261, Training accuracy: 0.9524, Test Loss: 0.7892, Test accuracy: 0.5000
# Epoch 7/20, Training Loss: 0.3770, Training accuracy: 0.8810, Test Loss: 0.8815, Test accuracy: 0.5000
# Epoch 8/20, Training Loss: 0.3538, Training accuracy: 0.8571, Test Loss: 0.8660, Test accuracy: 0.5000
# Epoch 9/20, Training Loss: 0.3435, Training accuracy: 0.8571, Test Loss: 0.7742, Test accuracy: 0.5238
# Epoch 10/20, Training Loss: 0.3019, Training accuracy: 0.9048, Test Loss: 0.6878, Test accuracy: 0.5714
# Epoch 11/20, Training Loss: 0.2781, Training accuracy: 0.9286, Test Loss: 0.6165, Test accuracy: 0.6667
# Epoch 12/20, Training Loss: 0.2755, Training accuracy: 0.9286, Test Loss: 0.5938, Test accuracy: 0.7143
# Epoch 13/20, Training Loss: 0.2710, Training accuracy: 0.9286, Test Loss: 0.6229, Test accuracy: 0.7143
# Epoch 14/20, Training Loss: 0.2410, Training accuracy: 0.9286, Test Loss: 0.6709, Test accuracy: 0.6190
# Epoch 15/20, Training Loss: 0.2281, Training accuracy: 0.9048, Test Loss: 0.6631, Test accuracy: 0.6667
# Epoch 16/20, Training Loss: 0.2407, Training accuracy: 0.9048, Test Loss: 0.6156, Test accuracy: 0.6905
# Epoch 17/20, Training Loss: 0.2139, Training accuracy: 0.9048, Test Loss: 0.5853, Test accuracy: 0.7143
# Epoch 18/20, Training Loss: 0.1939, Training accuracy: 0.9286, Test Loss: 0.5299, Test accuracy: 0.7857
# Epoch 19/20, Training Loss: 0.1810, Training accuracy: 0.9524, Test Loss: 0.5046, Test accuracy: 0.7857
# Epoch 20/20, Training Loss: 0.1860, Training accuracy: 0.9524, Test Loss: 0.4885, Test accuracy: 0.8095

# %%
from utils import LastLayer

resnet = models.resnet18(weights="DEFAULT")
fc = LastLayer()  # !  Important : No argument
fc.load_state_dict(torch.load("lastlayer.pth", weights_only=True))
resnet.fc = fc
resnet.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): LastLayer(
#     (fc): Linear(in_features=512, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ## Question 4 :
# > Perform  LoRA https://arxiv.org/pdf/2106.09685  on the model  (We are perfectly fine if you use an external library **for this question only**, and of course use it in the next questions). (Warning : without data augmentation it may not improve the accuracy.)
#
# Intermediate question : Describe LoRA. There are different ways of implementing LoRa for convolutions. You can choose your preferred one. Explain the version of LoRa you used, provide a drawing of the process in the `drawing_lora.png` file. (Hint: you can obtain a small rank convolution by combining a convolution and a 1x1 convolution. One of the two goes from a higher number of channels to a lower number of channels and the other one restores the number of channels.)

# %% [markdown]
# <div class="alert alert-info">  LoRA stands for low rank approximation, and is described in https://arxiv.org/pdf/2106.09685.  </div>.

# %% [markdown]
# A linear layer $h = Wx$ with $W \in \mathbb{R}^{d \times k}$ is first decomposed in $W = W_0x + \Delta Wx$ where $W_0$ is frozen during training, and gradients flow through $\Delta W$ only. Then we pose $\Delta W = BA$ with $B \in \mathbb{R}^{d \times k}, A \in \mathbb{R}^{r \times k}$ and the rank $r$ verifies $r \ll \text{min}(d,k)$

# %%
class LoRAConv2d(nn.Module):
    def __init__(self, conv_layer: nn.Conv2d, r: int = 4):
        super(LoRAConv2d, self).__init__()
        # Freeze the original convolution weights.
        self.conv = conv_layer
        self.conv.weight.requires_grad = False

        # Use the same stride as the original conv layer so that the spatial dimensions match.
        self.lora_down = nn.Conv2d(
            conv_layer.in_channels, r, kernel_size=1, stride=conv_layer.stride, bias=False
        )
        self.lora_up = nn.Conv2d(
            r, conv_layer.out_channels, kernel_size=1, stride=1, bias=False
        )
        # Initialize the up projection to zeros so that initially the module behaves like the original conv.
        nn.init.zeros_(self.lora_up.weight)

    def forward(self, x):
        # The original conv output and the LoRA branch output now have matching spatial dimensions.
        return self.conv(x) + self.lora_up(self.lora_down(x))

# %%
def apply_lora(model: nn.Module, r: int = 4):
    for name, module in list(model.named_children()):
        if isinstance(module, nn.Conv2d):
            setattr(model, name, LoRAConv2d(module, r=r))
        else:
            # Recursively apply LoRA to submodules.
            apply_lora(module, r=r)
    return model

# Create your model and apply LoRA
lora_model = models.resnet18(weights="DEFAULT")
lora_model.fc = LastLayer()  # use your custom last layer if needed
lora_model = apply_lora(lora_model, r=4).to(device)

# At this point, only the parameters of the LoRA adapters (lora_down and lora_up) and any unfrozen parts (e.g., fc) have requires_grad=True.
# Create an optimizer that only updates the trainable parameters.
optimizer = optim.Adam(filter(lambda p: p.requires_grad, lora_model.parameters()), lr=1e-3)
criterion = nn.CrossEntropyLoss()

# %%
train_losses, train_accuracies, test_losses, test_accuracies = training(
    lora_model, 
    training_dataloader, 
    test_dataloader, 
    criterion, 
    optimizer, 
    num_epochs=20)

plot_results(train_losses, train_accuracies, test_losses, test_accuracies)

# Save the LoRA model state dictionary
torch.save(lora_model.state_dict(), "lora_resnet.pth")
# Out:
# Epoch 1/20, Training Loss: 0.6798, Training accuracy: 0.7143, Test Loss: 0.6893, Test accuracy: 0.5476
# Epoch 2/20, Training Loss: 0.4822, Training accuracy: 0.7857, Test Loss: 0.7021, Test accuracy: 0.5238
# Epoch 3/20, Training Loss: 0.3585, Training accuracy: 0.8810, Test Loss: 0.8101, Test accuracy: 0.5000
# Epoch 4/20, Training Loss: 0.2574, Training accuracy: 0.9286, Test Loss: 0.9948, Test accuracy: 0.5000
# Epoch 5/20, Training Loss: 0.2131, Training accuracy: 0.9286, Test Loss: 1.0263, Test accuracy: 0.5000
# Epoch 6/20, Training Loss: 0.1586, Training accuracy: 0.9762, Test Loss: 0.9117, Test accuracy: 0.5238
# Epoch 7/20, Training Loss: 0.1180, Training accuracy: 0.9762, Test Loss: 0.8038, Test accuracy: 0.5714
# Epoch 8/20, Training Loss: 0.0858, Training accuracy: 1.0000, Test Loss: 0.7509, Test accuracy: 0.6429
# Epoch 9/20, Training Loss: 0.0624, Training accuracy: 1.0000, Test Loss: 0.7387, Test accuracy: 0.6667
# Epoch 10/20, Training Loss: 0.0547, Training accuracy: 1.0000, Test Loss: 0.7346, Test accuracy: 0.7143
# Epoch 11/20, Training Loss: 0.0603, Training accuracy: 1.0000, Test Loss: 0.7170, Test accuracy: 0.7143
# Epoch 12/20, Training Loss: 0.0445, Training accuracy: 1.0000, Test Loss: 0.6769, Test accuracy: 0.7619
# Epoch 13/20, Training Loss: 0.0194, Training accuracy: 1.0000, Test Loss: 0.5959, Test accuracy: 0.7619
# Epoch 14/20, Training Loss: 0.0207, Training accuracy: 1.0000, Test Loss: 0.5484, Test accuracy: 0.7619
# Epoch 15/20, Training Loss: 0.0144, Training accuracy: 1.0000, Test Loss: 0.5101, Test accuracy: 0.7857
# Epoch 16/20, Training Loss: 0.0124, Training accuracy: 1.0000, Test Loss: 0.4847, Test accuracy: 0.7857
# Epoch 17/20, Training Loss: 0.0086, Training accuracy: 1.0000, Test Loss: 0.4765, Test accuracy: 0.7857
# Epoch 18/20, Training Loss: 0.0067, Training accuracy: 1.0000, Test Loss: 0.4789, Test accuracy: 0.7857
# Epoch 19/20, Training Loss: 0.0054, Training accuracy: 1.0000, Test Loss: 0.4780, Test accuracy: 0.8095
# Epoch 20/20, Training Loss: 0.0041, Training accuracy: 1.0000, Test Loss: 0.4686, Test accuracy: 0.8095

# %% [markdown]
# ## Question 5 :
# In order to better train our LORA weights, let's do some Data Augmentation https://en.wikipedia.org/wiki/Data_augmentation . Load some alteration of the data from the `torchvision.transforms` module and incorporate them in your training pipeline.
#
#  Intermediate question : Check CutMix  (https://pytorch.org/vision/stable/auto_examples/transforms/plot_cutmix_mixup.html#sphx-glr-auto-examples-transforms-plot-cutmix-mixup-py) and explain it with a small drawing `cutmix.png`.
#
#
#   Provide one file : (https://pytorch.org/tutorials/beginner/saving_loading_models.html)
#  -  a `daug_resnet.pth` file containing the weight of the ResNet18 after DAUG  (  !  It  has to be of the class ResNet so you have to merge LoRA weights with the ResNet18 weights)

# %%
## Data Augmentation
from torchvision.transforms import v2

# Define the data augmentation/transforms pipeline
tsfm = v2.Compose([
    v2.RandomHorizontalFlip(),
    v2.RandomRotation(45),
    v2.Resize((224, 224)),
    v2.ToTensor(),
])

# apply the transforms to the dataset
transformed_north_dataset = datasets.ImageFolder(
    dir_path + "north_dataset_sample",
    transform=tsfm
)

# Create a DataLoader for the transformed dataset
transformed_dataloader = DataLoader(transformed_north_dataset, batch_size=32, shuffle=True)
# Out:
# /home/benjamin.deporte/.conda/envs/torchy/lib/python3.12/site-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
# We apply LoRA to get a new low-rank model
lora_model = models.resnet18(weights="DEFAULT")
lora_model.fc = LastLayer()  # use your custom last layer if needed
lora_model = apply_lora(lora_model, r=4).to(device)

assert isinstance(lora_model, models.ResNet)

# %%
# At this point, only the parameters of the LoRA adapters (lora_down and lora_up) and any unfrozen parts (e.g., fc) have requires_grad=True.
# Create an optimizer that only updates the trainable parameters.
optimizer = optim.Adam(filter(lambda p: p.requires_grad, lora_model.parameters()), lr=1e-3)
criterion = nn.CrossEntropyLoss()

# %%
train_losses, train_accuracies, test_losses, test_accuracies = training(
    lora_model, 
    transformed_dataloader, 
    test_dataloader, 
    criterion, 
    optimizer, 
    num_epochs=20)

plot_results(train_losses, train_accuracies, test_losses, test_accuracies)

torch.save(lora_model.state_dict(), "daug_resnet.pth")
# Out:
# Epoch 1/20, Training Loss: 0.7069, Training accuracy: 0.6905, Test Loss: 0.9863, Test accuracy: 0.5000
# Epoch 2/20, Training Loss: 0.5465, Training accuracy: 0.7381, Test Loss: 0.8916, Test accuracy: 0.5000
# Epoch 3/20, Training Loss: 0.4686, Training accuracy: 0.7619, Test Loss: 0.7741, Test accuracy: 0.5000
# Epoch 4/20, Training Loss: 0.4070, Training accuracy: 0.8571, Test Loss: 0.6914, Test accuracy: 0.5238
# Epoch 5/20, Training Loss: 0.3979, Training accuracy: 0.8333, Test Loss: 0.6997, Test accuracy: 0.5476
# Epoch 6/20, Training Loss: 0.3107, Training accuracy: 0.9048, Test Loss: 0.8239, Test accuracy: 0.5476
# Epoch 7/20, Training Loss: 0.2367, Training accuracy: 0.9524, Test Loss: 0.8749, Test accuracy: 0.5476
# Epoch 8/20, Training Loss: 0.2750, Training accuracy: 0.9286, Test Loss: 0.8577, Test accuracy: 0.5476
# Epoch 9/20, Training Loss: 0.2104, Training accuracy: 0.9286, Test Loss: 0.7163, Test accuracy: 0.6190
# Epoch 10/20, Training Loss: 0.1668, Training accuracy: 0.9524, Test Loss: 0.5812, Test accuracy: 0.7143
# Epoch 11/20, Training Loss: 0.1949, Training accuracy: 0.9048, Test Loss: 0.4933, Test accuracy: 0.7619
# Epoch 12/20, Training Loss: 0.1334, Training accuracy: 0.9524, Test Loss: 0.4087, Test accuracy: 0.8333
# Epoch 13/20, Training Loss: 0.1192, Training accuracy: 0.9762, Test Loss: 0.3805, Test accuracy: 0.8333
# Epoch 14/20, Training Loss: 0.1021, Training accuracy: 0.9524, Test Loss: 0.3634, Test accuracy: 0.8333
# Epoch 15/20, Training Loss: 0.0939, Training accuracy: 0.9762, Test Loss: 0.3680, Test accuracy: 0.8333
# Epoch 16/20, Training Loss: 0.0710, Training accuracy: 0.9762, Test Loss: 0.3708, Test accuracy: 0.8333
# Epoch 17/20, Training Loss: 0.0816, Training accuracy: 0.9762, Test Loss: 0.3782, Test accuracy: 0.8333
# Epoch 18/20, Training Loss: 0.0595, Training accuracy: 1.0000, Test Loss: 0.3479, Test accuracy: 0.8333
# Epoch 19/20, Training Loss: 0.0590, Training accuracy: 1.0000, Test Loss: 0.3313, Test accuracy: 0.8333
# Epoch 20/20, Training Loss: 0.0424, Training accuracy: 1.0000, Test Loss: 0.3194, Test accuracy: 0.8571

# %% [markdown]
# From the Pytorch doc : MixUp and CutMix are augmentation techniques that work on batches.
#
# <img src="cutmix_mixup.png" alt="Alternative text" />

# %% [markdown]
# ## Question 6 : (BONUS)
# > Do the best you can : improve performance on test set while keeping ResNet 18 architecture, or decrease the size of the model
#
# Provide a file  `final_model.pth` containing the weights of the final model and provide the class `FinalModel()` in the `utils.py` file.
